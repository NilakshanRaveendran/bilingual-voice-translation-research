# %% [markdown]
# <a href="https://colab.research.google.com/github/NilakshanRaveendran/bilingual-voice-translation-research/blob/main/notebooks/Research_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

BASE_DIR = "/content/drive/MyDrive/bilingual_voice_translation"
RAW_DIR = f"{BASE_DIR}/data/raw"
PROC_DIR = f"{BASE_DIR}/data/processed"
SEG_DIR = f"{BASE_DIR}/data/segments"

os.makedirs(RAW_DIR, exist_ok=True)
os.makedirs(PROC_DIR, exist_ok=True)
os.makedirs(SEG_DIR, exist_ok=True)

print("Folders created successfully")
# Out:
# Folders created successfully

# %%
# !git clone https://github.com/NilakshanRaveendran/bilingual-voice-translation-research.git
# Out:
# Cloning into 'bilingual-voice-translation-research'...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 41 (delta 18), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (41/41), 59.33 KiB | 1.04 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
